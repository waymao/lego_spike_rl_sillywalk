# %%
import time
import serial

# %%
s = serial.Serial("/dev/tty.usbmodem3285358433381",9600,timeout = 2)

# %%
while True:
    s.write(b'cmd1 ')
    print(s.readline())
    time.sleep(0.1)
# Out:
# b'25, 0]], [48, [0, 0, 163, 0]], [0, []], [49, [0, 0, -2, 0]], [0, []], [0, []], [0, 50, 986], [0, 0, 0], [43, 2, 0], "00900:09900:00900:00900:09990", 0]}\r{"m":0,"p":[[48, [0, -1, -25, 0]], [48, [0, 0, 163, 0]], [0, []], [49, [0, 0, -2, 0]], [0, []], [0, []], [0, 49, 986], [0, 0, 0], [43, 2, 0], "00900:09900:00900:00900:09990", 0]}\r{"m":0,"p":[[48, [0, -1, -25, 0]], [48, [0, 0, 163, 0]], [0, []], [49, [0, 0, -3, 0]], [0, []], [0, []], [-1, 48, 986], [0, 0, 0], [43, 2, 0], "00900:09900:00900:00900:09990", 0]}\r{"m":0,"p":[[48, [0, -1, -25, 0]], [48, [0, 0, 163, 0]], [0, []], [49, [0, 0, -2, 0]], [0, []], [0, []], [-3, 49, 986], [0, 0, 0], [43, 2, 0], "00900:09900:00900:00900:09990", 0]}\r{"m":0,"p":[[48, [0, -1, -25, 0]], [48, [0, 0, 163, 0]], [0, []], [49, [0, 0, -2, 0]], [0, []], [0, []], [-2, 49, 986], [0, 0, 0], [43, 2, 0], "00900:09900:00900:00900:09990", 0]}\r{"m":0,"p":[[48, [0, -1, -25, 0]], [48, [0, 0, 163, 0]], [0, []], [49, [0, 0, -2, 0]], [0, []], [0, []], [-2, 49, 985],
# ...
